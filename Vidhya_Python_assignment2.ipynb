# %% [markdown]
# PYTHON ASSIGNMENT 2 - LISTS,NESTED LISTS,FUNCTIONS, SETS.

# %%
bank = [
    [
        [
            ["C101", "Rahul", "Savings", 85000],
            ["C102", "Anita", "Current", 150000],
            ["C103", "Kiran", "Loan", 500000]
        ],
        [
            ["C104", "Sneha", "Savings", 95000],
            ["C105", "Vikram", "Current", 275000],
            ["C106", "Meena", "Loan", 750000]
        ]
    ],

    [
        [
            ["C201", "Arjun", "Savings", 120000],
            ["C202", "Pooja", "Current", 325000],
            ["C203", "Ramesh", "Loan", 900000]
        ],
        [
            ["C204", "Priya", "Savings", 45000],
            ["C205", "Amit", "Current", 185000],
            ["C206", "Divya", "Loan", 650000]
        ]
    ],

    [
        [
            ["C301", "Nikhil", "Savings", 78000],
            ["C302", "Kavya", "Current", 240000],
            ["C303", "Suresh", "Loan", 1000000]
        ],
        [
            ["C304", "Neha", "Savings", 135000],
            ["C305", "Rohan", "Current", 410000],
            ["C306", "Asha", "Loan", 550000]
        ]
    ]
]

# %%
# 1. Print Rahul's complete record.
print(bank[0][0][0])

# 2. Print Anita's account type.
print(bank[0][0][1][2])

# 3. Print Kiran's loan amount.
print(bank[0][0][2][3])

# 4. Print Sneha's customer ID.
print(bank[0][1][0][0])

# 5. Print Vikram's balance.
print(bank[0][1][1][3])

# 6. Print Meena's complete record.
print(bank[0][1][2])

# 7. Print Arjun's customer ID.
print(bank[1][0][0][0])

# 8. Print Pooja's name.
print(bank[1][0][1][1])

# 9. Print Ramesh's account type.
print(bank[1][0][2][2])

# 10. Print Priya's balance.
print(bank[1][1][0][3])

# 11. Print Amit's account type.
print(bank[1][1][1][2])

# 12. Print Divya's customer ID.
print(bank[1][1][2][0])

# 13. Print Nikhil's account type.
print(bank[2][0][0][2])

# 14. Print Kavya's balance.
print(bank[2][0][1][3])

# 15. Print Suresh's loan amount.
print(bank[2][0][2][3])

# 16. Print Neha's name.
print(bank[2][1][0][1])

# 17. Print Rohan's complete record.
print(bank[2][1][1])

# 18. Print Asha's account type.
print(bank[2][1][2][2])

# 19. Print all customers in Bank 1, Branch 1.
print(bank[0][0])

# 20. Print all customers in Bank 1, Branch 2.
print(bank[0][1])

# 21. Print all customers in Bank 2, Branch 1.
print(bank[1][0])

# 22. Print all customers in Bank 2, Branch 2.
print(bank[1][1])

# 23. Print all customers in Bank 3, Branch 1.
print(bank[2][0])

# 24. Print all customers in Bank 3, Branch 2.
print(bank[2][1])

# 25. Print all branches of Bank 1.
print(bank[0])

# 26. Print all branches of Bank 2.
print(bank[1])

# 27. Print all branches of Bank 3.
print(bank[2])

# 28. Print the first customer from every bank's first branch.
print(bank[0][0][0])
print(bank[1][0][0])
print(bank[2][0][0])

# 29. Print the second customer from every bank's second branch.
print(bank[0][1][1])
print(bank[1][1][1])
print(bank[2][1][1])

# 30. Print the loan amount of the last customer in Bank 3, Branch 2.
print(bank[2][1][2][3])
# Out:
# ['C101', 'Rahul', 'Savings', 85000]
# Current
# 500000
# C104
# 275000
# ['C106', 'Meena', 'Loan', 750000]
# C201
# Pooja
# Loan
# 45000
# Current
# C206
# Savings
# 240000
# 1000000
# Neha
# ['C305', 'Rohan', 'Current', 410000]
# Loan
# [['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]]
# [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]
# [['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]]
# [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]
# [['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]]
# [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]
# [[['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]], [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]]
# [[['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]], [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]]
# [[['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]], [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]]
# ['C101', 'Rahul', 'Savings', 85000]
# ['C201', 'Arjun', 'Savings', 120000]
# ['C301', 'Nikhil', 'Savings', 78000]
# ['C105', 'Vikram', 'Current', 275000]
# ['C205', 'Amit', 'Current', 185000]
# ['C305', 'Rohan', 'Current', 410000]
# 550000

# %% [markdown]
# 1. Create a list of 5 employee names and add a new employee using `append()`.
#
# 2. Create a list of account numbers and add three new account numbers using `extend()`.
#
# 3. Insert a new customer at the beginning of a customer list using `insert()`.
#
# 4. Insert a transaction amount at index 3 in a list.
#
# 5. Remove the last item from a list using `pop()`.
#
# 6. Remove the customer "Rahul" from a customer list using `remove()`.
#
# 7. Count how many times the account type "Savings" appears in a list using `count()`.
#
# 8. Find the index of "Current" in a list of account types using `index()`.
#
# 9. Reverse a list of transaction IDs using `reverse()`.
#
# 10. Sort a list of account balances in ascending order using `sort()`.
#
# 11. Sort a list of customer names in descending order using `sort()`.
#
# 12. Make a copy of a list using `copy()` and verify that modifying the copied list does not affect the original list.
#
# 13. Clear all elements from a list using `clear()`.
#
# 14. Append a nested list containing a new customer's details to an existing customer list.
#
# 15. Extend a list of branch names with another list of new branches.
#
# 16. Remove the first occurrence of the balance `50000` from a list using `remove()`.
#
# 17. Pop the element at index 2 from a list and print the removed value.
#
# 18. Count how many times the city "Bangalore" appears in a list.
#
# 19. Reverse a list of bank names and print the result.
#
# 20. Create a list of loan amounts and sort it in descending order.

# %%
#1
employees = ["Rahul", "Anita", "Kiran", "Sneha", "Vikram"]

employees.append("Meena")

print(employees)

#2
accounts = [101, 102, 103]

accounts.extend([104, 105, 106])

print(accounts)

#3
customers = ["Rahul", "Anita", "Kiran"]

customers.insert(0, "Meena")

print(customers)

#4
transactions = [1000, 2000, 3000, 5000]

transactions.insert(3, 4000)

print(transactions)

#5
customers = ["Rahul", "Anita", "Kiran", "Sneha"]

customers.pop()

print(customers)

#6
customers = ["Rahul", "Anita", "Kiran", "Sneha"]

customers.remove("Rahul")

print(customers)

#7
account_types = ["Savings", "Current", "Savings", "Loan", "Savings"]

print(account_types.count("Savings"))

#8
account_types = ["Savings", "Current", "Loan"]

print(account_types.index("Current"))

#9
transaction_ids = [101, 102, 103, 104, 105]

transaction_ids.reverse()

print(transaction_ids)

#10
balances = [85000, 120000, 45000, 95000, 275000]

balances.sort()

print(balances)

#11
customers = ["Rahul", "Anita", "Kiran", "Sneha", "Vikram"]

customers.sort(reverse=True)

print(customers)

#12
customers = ["Rahul", "Anita", "Kiran"]

copied_list = customers.copy()

copied_list.append("Sneha")

print("Original List:", customers)

print("Copied List:", copied_list)

#13
customers = ["Rahul", "Anita", "Kiran"]

customers.clear()

print(customers)

#14
customers = [
    ["C101", "Rahul", "Savings", 85000],
    ["C102", "Anita", "Current", 150000]
]

customers.append(["C103", "Kiran", "Loan", 500000])

print(customers)

#15
branches = ["MG Road", "Indiranagar"]

new_branches = ["Whitefield", "Electronic City"]

branches.extend(new_branches)

print(branches)

#16
balances = [85000, 50000, 120000, 50000, 275000]

balances.remove(50000)

print(balances)

#17
customers = ["Rahul", "Anita", "Kiran", "Sneha"]

removed = customers.pop(2)

print("Removed:", removed)

print(customers)

#18
cities = ["Bangalore", "Hyderabad", "Bangalore", "Chennai", "Bangalore"]

print(cities.count("Bangalore"))

#19
banks = ["SBI", "HDFC", "ICICI", "Axis"]

banks.reverse()

print(banks)

#20
loan_amounts = [500000, 750000, 900000, 650000]

loan_amounts.sort(reverse=True)

print(loan_amounts)
# Out:
# ['Rahul', 'Anita', 'Kiran', 'Sneha', 'Vikram', 'Meena']
# [101, 102, 103, 104, 105, 106]
# ['Meena', 'Rahul', 'Anita', 'Kiran']
# [1000, 2000, 3000, 4000, 5000]
# ['Rahul', 'Anita', 'Kiran']
# ['Anita', 'Kiran', 'Sneha']
# 3
# 1
# [105, 104, 103, 102, 101]
# [45000, 85000, 95000, 120000, 275000]
# ['Vikram', 'Sneha', 'Rahul', 'Kiran', 'Anita']
# Original List: ['Rahul', 'Anita', 'Kiran']
# Copied List: ['Rahul', 'Anita', 'Kiran', 'Sneha']
# []
# [['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]]
# ['MG Road', 'Indiranagar', 'Whitefield', 'Electronic City']
# [85000, 120000, 50000, 275000]
# Removed: Kiran
# ['Rahul', 'Anita', 'Sneha']
# 3
# ['Axis', 'ICICI', 'HDFC', 'SBI']
# [900000, 750000, 650000, 500000]

# %%
# Sample Sets

bank_branches = {"MG Road", "Indiranagar", "Whitefield", "Electronic City"}

customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}

new_customers = {"Amit", "Priya", "Rahul", "Divya"}

loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}

savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}

transaction_ids = {101, 102, 103, 104, 105}

balances = {85000, 120000, 45000, 95000, 275000}

cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}

new_cities = {"Mumbai", "Bangalore", "Delhi"}

account_types = {"Savings", "Current", "Loan"}

# %%
# Sample Sets (Re-initializing for this cell's context due to variable redefinition in prior cells)
bank_branches = {"MG Road", "Indiranagar", "Whitefield", "Electronic City"}
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}
transaction_ids = {101, 102, 103, 104, 105}
balances = {85000, 120000, 45000, 95000, 275000}
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
new_cities = {"Mumbai", "Bangalore", "Delhi"}
account_types = {"Savings", "Current", "Loan"}

#1

print(customers)

#2

print(len(customers))

#3

print("Rahul" in customers)

#4

print("Meena" in customers)

#5
for branch in bank_branches:
    print(branch)

#6
customers.add("Meena")
print(customers)

#7

cities.add("Mysore")
print(cities)

#8
customers.update(new_customers)
print(customers)

#9
cities.update(new_cities)
print(cities)

#10
customers.remove("Rahul")
print(customers)

#11
cities.remove("Pune")
print(cities)

#12

customers.discard("Anita")
print(customers)

#13
cities.discard("Delhi")
print(cities)

#14
cities.discard("Kolkata")
print(cities)

#15
removed = transaction_ids.pop()

print("Removed:", removed)
print(transaction_ids)

#16
removed = account_types.pop()

print("Removed:", removed)
print(account_types)

#17
# Moving balances.clear() to after the operations that use 'balances'
# to avoid ValueError: max() iterable argument is empty

#29
print(max(balances))

#30
print(min(balances))

#31
print(sum(balances))

#32
print(sorted(balances))

balances.clear()
print(balances)

#18
copied_customers = customers.copy()

print(copied_customers)

#19
copied_customers = customers.copy()

copied_customers.add("Meena")

print("Original:", customers)
print("Copied:", copied_customers)

#20
print(customers.union(new_customers))

#21
print(customers.intersection(new_customers))

#22
print(savings_customers.intersection(loan_customers))

#23
print(customers.difference(new_customers))

#24
print(savings_customers.difference(loan_customers))

#25
print(customers.symmetric_difference(new_customers))

#26
print({"Rahul", "Kiran"}.issubset(loan_customers))

#27
print(customers.issuperset({"Rahul", "Anita"}))

#28
print(loan_customers.isdisjoint(new_cities))

#33
customer_list = list(customers)

print(customer_list)

#34
city_tuple = tuple(cities)

print(city_tuple)

#35
names = ["Rahul", "Rahul", "Anita", "Sneha", "Sneha"]

unique_names = set(names)

print(unique_names)

#36
employees = set()

print(employees)

#37
employees = set()

employees.add("Rahul")
employees.add("Anita")
employees.add("Kiran")
employees.add("Sneha")
employees.add("Vikram")

print(employees)

#38
print(len(account_types))

#39
for customer in loan_customers:
    print(customer)

#40
transaction_ids.clear()

print(transaction_ids)
# Out:
# {'Rahul', 'Anita', 'Sneha', 'Kiran', 'Vikram'}
# 5
# True
# False
# MG Road
# Indiranagar
# Whitefield
# Electronic City
# {'Rahul', 'Anita', 'Sneha', 'Meena', 'Kiran', 'Vikram'}
# {'Chennai', 'Bangalore', 'Mysore', 'Pune', 'Hyderabad'}
# {'Anita', 'Sneha', 'Priya', 'Vikram', 'Kiran', 'Amit', 'Meena', 'Divya', 'Rahul'}
# {'Chennai', 'Mumbai', 'Bangalore', 'Mysore', 'Delhi', 'Pune', 'Hyderabad'}
# {'Anita', 'Sneha', 'Priya', 'Vikram', 'Kiran', 'Amit', 'Meena', 'Divya'}
# {'Chennai', 'Mumbai', 'Bangalore', 'Mysore', 'Delhi', 'Hyderabad'}
# {'Sneha', 'Priya', 'Vikram', 'Kiran', 'Amit', 'Meena', 'Divya'}
# {'Chennai', 'Mumbai', 'Bangalore', 'Mysore', 'Hyderabad'}
# {'Chennai', 'Mumbai', 'Bangalore', 'Mysore', 'Hyderabad'}
# Removed: 101
# {102, 103, 104, 105}
# Removed: Current
# {'Savings', 'Loan'}
# 275000
# 45000
# 620000
# [45000, 85000, 95000, 120000, 275000]
# set()
# {'Amit', 'Divya', 'Sneha', 'Meena', 'Priya', 'Vikram', 'Kiran'}
# Original: {'Sneha', 'Priya', 'Vikram', 'Kiran', 'Amit', 'Meena', 'Divya'}
# Copied: {'Amit', 'Divya', 'Sneha', 'Meena', 'Priya', 'Vikram', 'Kiran'}
# {'Sneha', 'Priya', 'Vikram', 'Rahul', 'Amit', 'Meena', 'Divya', 'Kiran'}
# {'Priya', 'Amit', 'Divya'}
# {'Rahul'}
# {'Kiran', 'Vikram', 'Sneha', 'Meena'}
# {'Priya', 'Nikhil', 'Sneha'}
# {'Sneha', 'Vikram', 'Kiran', 'Meena', 'Rahul'}
# True
# False
# True
# ['Sneha', 'Priya', 'Vikram', 'Kiran', 'Amit', 'Meena', 'Divya']
# ('Chennai', 'Mumbai', 'Bangalore', 'Mysore', 'Hyderabad')
# {'Rahul', 'Anita', 'Sneha'}
# set()
# {'Anita', 'Sneha', 'Vikram', 'Kiran', 'Rahul'}
# 2
# Rahul
# Ramesh
# Asha
# Kiran
# set()
