# %% [markdown]
# DATA SCIENCE ASSIGNMENT 1 - **POSITIVE AND NEGATIVE INDEXING**

# %%
text = "Edukron Data Science and Data Engineering Batch 2026"

# %%
for i in range(len(text)) :
    print(i,text[i])
# Out:
# 0 E
# 1 d
# 2 u
# 3 k
# 4 r
# 5 o
# 6 n
# 7
# 8 D
# 9 a
# 10 t
# 11 a
# 12
# 13 S
# 14 c
# 15 i
# 16 e
# 17 n
# 18 c
# 19 e
# 20
# 21 a
# 22 n
# 23 d
# 24
# 25 D
# 26 a
# 27 t
# 28 a
# 29
# 30 E
# 31 n
# 32 g
# 33 i
# 34 n
# 35 e
# 36 e
# 37 r
# 38 i
# 39 n
# 40 g
# 41
# 42 B
# 43 a
# 44 t
# 45 c
# 46 h
# 47
# 48 2
# 49 0
# 50 2
# 51 6

# %%
for i in range(-len(text),0):
    print(i,text[i])
# Out:
# -52 E
# -51 d
# -50 u
# -49 k
# -48 r
# -47 o
# -46 n
# -45
# -44 D
# -43 a
# -42 t
# -41 a
# -40
# -39 S
# -38 c
# -37 i
# -36 e
# -35 n
# -34 c
# -33 e
# -32
# -31 a
# -30 n
# -29 d
# -28
# -27 D
# -26 a
# -25 t
# -24 a
# -23
# -22 E
# -21 n
# -20 g
# -19 i
# -18 n
# -17 e
# -16 e
# -15 r
# -14 i
# -13 n
# -12 g
# -11
# -10 B
# -9 a
# -8 t
# -7 c
# -6 h
# -5
# -4 2
# -3 0
# -2 2
# -1 6

# %% [markdown]
# 1. Write the indexing expression to print *"Edukron"*.
#
#    Answer:

# %%
print("positive indexing -",text[0:7])
print("negative indexing -",text[-52:-45])
# Out:
# positive indexing - Edukron
# negative indexing - Edukron

# %% [markdown]
# 2. Write the indexing expression to print *"Data"* (first occurrence).
#
#    Answer:

# %%
print(text[8:12])       #positive
print(text[-44:-40])    #negative
# Out:
# Data
# Data

# %% [markdown]
# 3. Write the indexing expression to print *"Science"*.
#
#    Answer:

# %%
print(text[13:20])     # positive
print(text[-39:-32])   # negative indexing
# Out:
# Science
# Science

# %% [markdown]
# 4. Write the indexing expression to print *"and"*.
#
#    Answer:

# %%
print(text[21:24])      # positive indexing
print(text[-31:-28])    # negative
# Out:
# and
# and

# %% [markdown]
# 5. Write the indexing expression to print *"Data Engineering"*.
#
#    Answer:

# %%
print(text[25:41])        # +ve indexing expression
print(text[-27:-11])      # -ve indexing expression
# Out:
# Data Engineering
# Data Engineering

# %% [markdown]
# 6. Write the indexing expression to print *"Engineering"*.
#
#    Answer:

# %%
print(text[30:41])       # positive
print(text[-22:-11])     # negative
# Out:
# Engineering
# Engineering

# %% [markdown]
# 7. Write the indexing expression to print *"Batch"*.
#
#    Answer:

# %%
print(text[42:47])
print(text[-10:-5])
# Out:
# Batch
# Batch

# %% [markdown]
# 8. Write the indexing expression to print *"2026"*.
#
#    Answer:

# %%
print(text[48:])
print(text[-4:])
# Out:
# 2026
# 2026

# %% [markdown]
# 9. Write the indexing expression to print *"Science and Data"*.
#
#    Answer:

# %%
print(text[13:29])
print(text[-39:-23])
# Out:
# Science and Data
# Science and Data

# %% [markdown]
# 10. Write the indexing expression to print *"Data Science and Data Engineering Batch"*.
#
#     Answer:

# %%
print(text[8:47])
print(text[-44:-5])
# Out:
# Data Science and Data Engineering Batch
# Data Science and Data Engineering Batch
