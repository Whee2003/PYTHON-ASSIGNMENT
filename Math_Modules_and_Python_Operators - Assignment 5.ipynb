# %%
import math
math.factorial(5)
# Out:
# 120

# %%
5*4*3*2*1
# Out:
# 120

# %%
n*n-1*n-2*n-3 ==$ untill becomes 1
# Out:
#   File "/tmp/ipykernel_941/929181079.py", line 1
#     n*n-1*n-2*n-3 ==$ untill becomes 1
#                     ^
# SyntaxError: invalid syntax

# %%
math.gcd(18,24)   ### GCD (Greatest common divisior)
# Out:
# 6

# %%
math.sqrt(64)
# Out:
# 8.0

# %%
math.pow(64,0.5)   ### exponent of a value

64 is the base value
0.5 is the exponent
# Out:
#   File "/tmp/ipykernel_941/215947736.py", line 3
#     64 is the base value
#               ^
# SyntaxError: invalid syntax

# %%
math.cbrt(27) ## cube root
# Out:
# 3.0000000000000004

# %%
math.pow(27,1/3)
# Out:
# 3.0

# %%
print(math.log(10))
print(math.log2(10))
print(math.log10(10))
# Out:
# 2.302585092994046
# 3.321928094887362
# 1.0

# %%
print(math.sin(90))
print(math.cos(90))
print(math.tan(90))
# Out:
# 0.8939966636005579
# -0.4480736161291701
# -1.995200412208242

# %%
print(math.asin(1))
print(math.acos(1))
print(math.atan(1))
# Out:
# 1.5707963267948966
# 0.0
# 0.7853981633974483

# %%
### hypot
math.hypot(3,4) ### distance from origin to a specific point
sqrt(3**2+4**2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_941/4262792235.py in <cell line: 0>()
#       1 ### hypot
#       2 math.hypot(3,4) ### distance from origin to a specific point
# ----> 3 sqrt(3**2+4**2)
#
# NameError: name 'sqrt' is not defined

# %%
math.isnan(math.nan)   ## Null values
# Out:
# True

# %%
math.inf
# Out:
# inf

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_941/2354412189.py in <cell line: 0>()
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
math.isinf(math.inf)
# Out:
# True

# %%
math.remainder(10,3)
# Out:
# 1.0

# %%
math.dist((1,2),(4,6))
# Out:
# 5.0

# %%
x=[[10,20],[30,40],[50,60],[31,21]]
# for i in range(0,len(x)):
#   for j in range(i+1,)
for i in x:
  for j in x:
    if i!=j:
      print(math.dist(i,j))
# Out:
# 28.284271247461902
# 56.568542494923804
# 21.02379604162864
# 28.284271247461902
# 28.284271247461902
# 19.026297590440446
# 56.568542494923804
# 28.284271247461902
# 43.382023926967726
# 21.02379604162864
# 19.026297590440446
# 43.382023926967726

# %%
distance: difference between 2 points
euclidean distance : sqrt((x2-x1)**2+(y2-y1)**2)
distance matrix : if i have 4 coordinates, we will calcuate 16 distances and put in
4*4 matrix this is called distance matrix
# Out:
#   File "/tmp/ipykernel_941/1442444172.py", line 1
#     distance: difference between 2 points
#                          ^
# SyntaxError: invalid syntax

# %%
bharath  9
madhu 7
aftab 4
afroz 2

# %%
0,12,14,15
12,0,23,21
12,13,0,21
11,12,13,0
# Out:
# (11, 12, 13, 0)

# %%
permutations
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_941/3705806251.py in <cell line: 0>()
# ----> 1 permutations
#
# NameError: name 'permutations' is not defined

# %%
combinations

# %%
math.perm(5,2)

# %%
npr
ncr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_941/238697114.py in <cell line: 0>()
# ----> 1 npr
#       2 ncr
#
# NameError: name 'npr' is not defined

# %%
math.comb(5,2)

# %%
def add(x,y,z):
  return x*y*z
add(40,20,20)
# Out:
# 16000

# %%
def add(x,y):
  print(x+y)
add(10,20)
add("data","science")
# Out:
# 30
# datascience

# %%
x=[10,20,30,"abc","bca",10,20]
def additions(x):
  strigconcat=""
  intaddition=0
  for i in x:
    if type(i)==str:
      strigconcat=strigconcat+" "+i
    else:
      intaddition=intaddition+i
  return [strigconcat,intaddition]
strigconcat,intaddition=additions(x)

# %%
intaddition
# Out:
# 90

# %%
strigconcat
# Out:
# ' abc bca'

# %% [markdown]
# # Python Math Module – 30 Coding Questions
#
# 1. Write a program to calculate the square root of a number using the `math` module.
# 2. Find the cube root of a given number using mathematical operations.
# 3. Calculate the factorial of a number using `math.factorial()`.
# 4. Find the GCD (Greatest Common Divisor) of two numbers using `math.gcd()`.
# 5. Find the LCM of two numbers using `math.lcm()`.
# 6. Calculate the value of 5 raised to the power of 8 using `math.pow()`.
# 7. Find the absolute value of a negative decimal number using `math.fabs()`.
# 8. Round a floating-point number up using `math.ceil()`.
# 9. Round a floating-point number down using `math.floor()`.
# 10. Round a floating-point number to the nearest integer using `round()`.
# 11. Find the remainder of two numbers using `math.fmod()`.
# 12. Find the quotient and remainder using `divmod()`.
# 13. Calculate the sine, cosine, and tangent of 45 degrees.
# 14. Convert an angle from degrees to radians.
# 15. Convert an angle from radians to degrees.
# 16. Find the logarithm (base 10) of a number using `math.log10()`.
# 17. Find the natural logarithm of a number using `math.log()`.
# 18. Calculate e raised to the power of x using `math.exp()`.
# 19. Find the value of π (`pi`) and Euler's number (`e`) from the `math` module.
# 20. Find the distance between two points using `math.dist()`.
# 21. Calculate the hypotenuse of a right triangle using `math.hypot()`.
# 22. Find the combination (nCr) using `math.comb()`.
# 23. Find the permutation (nPr) using `math.perm()`.
# 24. Check whether a number is finite, infinite, or NaN using `math.isfinite()`, `math.isinf()`, and `math.isnan()`.
# 25. Find the product of all numbers in a list using `math.prod()`.
# 26. Find the sum of square roots of all numbers in a list.
# 27. Find the largest integer less than or equal to the square root of a given number.
# 28. Calculate compound interest using `math.pow()`.
# 29. Find the area and circumference of a circle using `math.pi`.
# 30. Create a scientific calculator that supports square root, factorial, logarithm, power, trigonometric functions, GCD, and LCM.
#
# ---
#
# # Python Operators – 30 Coding Questions
#
# ## Arithmetic Operators
#
# 1. Write a program to perform addition, subtraction, multiplication, division, floor division, modulus, and exponentiation on two numbers.
# 2. Swap two numbers without using a third variable.
# 3. Find whether a number is even or odd using the modulus operator.
# 4. Reverse a three-digit number using arithmetic operators.
# 5. Find the last digit and first digit of a given number.
#
# ## Assignment Operators
#
# 6. Demonstrate all assignment operators (`=`, `+=`, `-=`, `*=`, `/=`, `//=`, `%=` and `**=`) on a variable.
# 7. Update a bank account balance using compound assignment operators.
# 8. Calculate the total marks using `+=` inside a loop.
#
# ## Comparison Operators
#
# 9. Compare two numbers and print the larger number.
# 10. Check whether three numbers are equal.
# 11. Find the largest among three numbers using comparison operators.
# 12. Check whether a student is eligible to vote based on age.
#
# ## Logical Operators
#
# 13. Check if a person is eligible for a loan (age > 21 AND salary > 30000).
# 14. Check if a number lies between 10 and 100 using logical operators.
# 15. Validate username and password using logical operators.
# 16. Determine whether a year is a leap year using logical conditions.
#
# ## Bitwise Operators
#
# 17. Find the bitwise AND, OR, XOR of two numbers.
# 18. Perform left shift and right shift operations.
# 19. Check whether a number is even using a bitwise operator.
# 20. Swap two numbers using the XOR operator.
# 21. Count how many bits are set to 1 in a number using bitwise operations.
#
# ## Identity Operators
#
# 22. Demonstrate the difference between `is` and `==`.
# 23. Check whether two variables refer to the same list object.
# 24. Show the behavior of `is not` with integers and lists.
#
# ## Membership Operators
#
# 25. Check whether a character exists in a string.
# 26. Check whether a number exists in a list.
# 27. Count how many vowels in a string belong to a predefined vowel list using `in`.
#
# ## Mixed Operator Programs
#
# 28. Build a simple calculator using arithmetic and comparison operators.
# 29. Create a grading system using comparison and logical operators.
# 30. Build a menu-driven calculator that uses arithmetic, comparison, logical, assignment, membership, identity, and bitwise operators wherever applicable.

# %% [markdown]
# MATH MODULE SOLUTIONS

# %%
#Q1
import math
num = 10
print(math.sqrt(num))
# Out:
# 3.1622776601683795

# %%
#2
num = 5
print(math.pow(num,1/3))
# Out:
# 1.7099759466766968

# %%
#3
num = 4
print(math.factorial(num))
# Out:
# 24

# %%
#4
print(math.gcd(4,40))
# Out:
# 4

# %%
#5
print(math.lcm(4,40))
# Out:
# 40

# %%
#6
print(math.pow(5,8))
# Out:
# 390625.0

# %%
#7
num = -8
print(math.fabs(num))
# Out:
# 8.0

# %%
#8
num = 3.75
print(math.ceil(num))
# Out:
# 4

# %%
#9
num = 9.6
print(math.floor(num))
# Out:
# 9

# %%
#10
num = 34.432
print(round(num))
# Out:
# 34

# %%
#11
num1 = 2
num2 = 9
print(math.fmod(num1,num2))
# Out:
# 2.0

# %%
#12
print(divmod(15,4))
# Out:
# (3, 3)

# %%
#13
print(math.sin(math.radians(45)))
print(math.cos(math.radians(45)))
print(math.tan(math.radians(45)))
# Out:
# 0.7071067811865475
# 0.7071067811865476
# 0.9999999999999999

# %%
#14
print(math.radians(90))
# Out:
# 1.5707963267948966

# %%
#15
angle = math.pi
print(math.degrees(angle))
# Out:
# 180.0

# %%
#16
print(math.log10(100))
# Out:
# 2.0

# %%
#17
print(math.log(100))
# Out:
# 4.605170185988092

# %%
#18
x = 5
print(math.exp(x))
# Out:
# 148.4131591025766

# %%
#19
PI = math.pi
E = math.e
print (PI,E)
# Out:
# 3.141592653589793 2.718281828459045

# %%
#20
point1 = (2,3)
point2 = (4,9)
print(math.dist(point1,point2))
# Out:
# 6.324555320336759

# %%
#21
base = 4
height = 7
print(math.hypot(base,height))
# Out:
# 8.06225774829855

# %%
#22
print(math.comb(5,2))
# Out:
# 10

# %%
#23
print(math.perm(5,2))
# Out:
# 20

# %%
#24
num = 56
print(math.isfinite(num))
print(math.isinf(num))
print(math.isnan(num))
# Out:
# True
# False
# False

# %%
#25
list = [1,2,3,4]
print(math.prod(list))
# Out:
# 24

# %%
#26
numbers = [1,2,3,4]
total = 0
for i in numbers :
  total = total + math.sqrt(i)
  print(total)
# Out:
# 1.0
# 2.414213562373095
# 4.146264369941973
# 6.146264369941973

# %%
#27
num = 20
print(math.floor(math.sqrt(num)))
# Out:
# 4

# %%
#28
P = 1000
R = 5
T = 2
A = P * math.pow(1+R/100,T)
print(A)
# Out:
# 1102.5

# %%
#29

r = 5
Area = math.pi*5*5
circumference = 2 * math.pi * r
print(Area)
print(circumference)
# Out:
# 78.53981633974483
# 31.41592653589793

# %%
#30
print("Square root :", math.sqrt(25))
print("Factorial:",math.factorial(25))
print("Logarithmic:", math.log(25))
print("Power:", math.pow(2,5))
print("sin :", math.sin(math.radians(45)))
print("cos :", math.cos(math.radians(45)))
print("tan :", math.tan(math.radians(45)))
print("gCD:", math.gcd(25,5))
print("LCM:", math.lcm(25,2))
# Out:
# Square root : 5.0
# Factorial: 15511210043330985984000000
# Logarithmic: 3.2188758248682006
# Power: 32.0
# sin : 0.7071067811865475
# cos : 0.7071067811865476
# tan : 0.9999999999999999
# gCD: 5
# LCM: 50

# %% [markdown]
# PYTHON OPERATORS

# %% [markdown]
# ARITHMETIC OPERATORS

# %%
# Q1

num1 = 6
num2 = 3
print("Addition :", num1 +num2)
print("Subtraction:", num1 - num2)
print("Multiplication :", num1*num2)
print("Division:", num1/num2)
print("Floor Division :",num1//num2)
print("Modulus :", num1 % num2)
print("Exponentiation :", num1 ** num2)
# Out:
# Addition : 9
# Subtraction: 3
# Multiplication : 18
# Division: 2.0
# Floor Division : 2
# Modulus : 0
# Exponentiation : 216

# %%
#Q2
num1 = 32
num2 = 10
print("Before Swap -", num1 , num2)

num1, num2 = num2,num1
print("After Swap -", num1 , num2)
# Out:
# Before Swap - 32 10
# After Swap - 10 32

# %%
#Q3
num = 37
if num % 2 == 0:
  print( "num is even")
else :
  print("num is odd")
# Out:
# num is odd

# %%
#Q4
num = 123
last_digit = num %10
middle_digit =(num//10)% 10
first_digit = num//100
reversed_num = (last_digit * 100) + (middle_digit * 10) + first_digit
print("original number :" , num)
print("reversed number :", reversed_num)
# Out:
# original number : 123
# reversed number : 321

# %%
#Q5
num = 2345
last_digit = num%10

while num >= 10:
  num = num//10

first_digit = num
print("last digit :", last_digit)
print("first digit :", first_digit)
# Out:
# last digit : 5
# first digit : 2

# %% [markdown]
# ASSIGNMENT OPERATORS

# %%
#Q6

x = 10
print("=:",x)
x += 5
print ("+=:", x)
x -= 5
print ("-=:", x )
x *= 5
print("*= :", x)
x /= 5
print("/=", x)
x //= 5
print ("//=", x)
x %= 15
print("%=",x)
x **= 5
print ("**=",x)
# Out:
# =: 10
# +=: 15
# -=: 10
# *= : 50
# /= 10.0
# //= 2.0
# %= 2.0
# **= 32.0

# %%
#Q7

Balance = 5000
print("Initial_Balance :" , Balance)

Balance += 2000
print("After_Deposit :" , Balance)

Balance -= 1000
print("After_Withdrawl :" , Balance)
# Out:
# Initial_Balance : 5000
# After_Deposit : 7000
# After_Withdrawl : 6000

# %%
#Q8
# Q8

marks = [80, 75, 90, 85]

total = 0

for i in marks:
    total += i

print("Total Marks:", total)
# Out:
# Total Marks: 330

# %% [markdown]
# COMPARISON OPERATORS

# %%
# Q9

num1 = 15
num2 = 20

if num1 > num2:
    print(num1, "is larger")
else:
    print(num2, "is larger")
# Out:
# 20 is larger

# %%
# Q10

num1 = 5
num2 = 5
num3 = 5

if num1 == num2 == num3:
    print("All numbers are equal")
else:
    print("Numbers are not equal")
# Out:
# All numbers are equal

# %%
# Q11

num1 = 20
num2 = 15
num3 = 18

if num1 > num2 and num1 > num3:
    print(num1, "is largest")

elif num2 > num1 and num2 > num3:
    print(num2, "is largest")

else:
    print(num3, "is largest")
# Out:
# 20 is largest

# %%
# Q12

age = 19

if age >= 18:
    print("Eligible to vote")

else:
    print("Not eligible")
# Out:
# Eligible to vote

# %% [markdown]
# LOGICAL OPERATORS

# %%
# Q13

age = 25
salary = 40000

if age > 21 and salary > 30000:
    print("Loan Approved")

else:
    print("Loan Rejected")
# Out:
# Loan Approved

# %%
# Q14

num = 56

if num >= 10 and num <=100:
    print("Number lies between 10 and 100")

else:
    print("Number is outside the range")
# Out:
# Number lies between 10 and 100

# %%
# Q15

username = "admin"
password = "1234"

if username == "admin" and password == "1234":
    print("Login Successful")

else:
    print("Invalid Username or Password")
# Out:
# Login Successful

# %%
# Q16

year = 2024

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")

else:
    print("Not a Leap Year")
# Out:
# Leap Year

# %% [markdown]
# BITWISE OPERATORS

# %%
# Q17

num1 = 5
num2 = 3

print("AND :", num1 & num2)
print("OR :", num1 | num2)
print("XOR :", num1 ^ num2)
# Out:
# AND : 1
# OR : 7
# XOR : 6

# %%
# Q18

num = 8

print("Left Shift :", num << 1)
print("Right Shift :", num >> 1)
# Out:
# Left Shift : 16
# Right Shift : 4

# %%
# Q19

num = 24

if num & 1 == 0:
    print("Even")

else:
    print("Odd")
# Out:
# Even

# %%
# Q20

a = 10
b = 20

print("Before Swap")
print(a,b)

a = a ^ b
b = a ^ b
a = a ^ b

print("After Swap")
print(a,b)
# Out:
# Before Swap
# 10 20
# After Swap
# 20 10

# %%
# Q21

num = 13

count = bin(num).count("1")

print(count)
# Out:
# 3

# %% [markdown]
# IDENTITY OPERATORS

# %%
# Q22

a = [1,2,3]
b = [1,2,3]

print(a == b)

print(a is b)
# Out:
# True
# False

# %%
# Q23

list1 = [1,2,3]

list2 = list1

print(list1 is list2)
# Out:
# True

# %%
# Q24

a = 10
b = 20

print(a is not b)

list1 = [1,2]

list2 = [1,2]

print(list1 is not list2)
# Out:
# True
# True

# %% [markdown]
# MEMBERSHIP OPERATORS

# %%
# Q25

text = "Python"

if "o" in text:
    print("Character Found")

else:
    print("Character Not Found")
# Out:
# Character Found

# %%
# Q26

numbers = [10,20,30,40]

if 30 in numbers:
    print("Number Found")

else:
    print("Number Not Found")
# Out:
# Number Found

# %%
# Q27

text = "Education"

count = 0

vowels = "aeiouAEIOU"

for i in text:

    if i in vowels:
        count += 1

print("Vowels =", count)
# Out:
# Vowels = 5

# %% [markdown]
# MIXED OPERATOR PROGRAMS

# %%
# Q28

num1 = 20
num2 = 10

print("Addition =",num1+num2)
print("Subtraction =",num1-num2)
print("Multiplication =",num1*num2)
print("Division =",num1/num2)

if num1 > num2:
    print(num1,"is greater")

else:
    print(num2,"is greater")
# Out:
# Addition = 30
# Subtraction = 10
# Multiplication = 200
# Division = 2.0
# 20 is greater

# %%
# Q29

marks = 78

if marks >=90:
    print("Grade A")

elif marks >=75:
    print("Grade B")

elif marks >=60:
    print("Grade C")

elif marks >=40:
    print("Grade D")

else:
    print("Fail")
# Out:
# Grade B

# %%
# Q30

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = int(input("Enter choice: "))

if choice == 1:
    print(num1 + num2)

elif choice == 2:
    print(num1 - num2)

elif choice == 3:
    print(num1 * num2)

elif choice == 4:
    print(num1 / num2)

else:
    print("Invalid Choice")
# Out:
# Enter first number: 15
# Enter second number: 2
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter choice: 1
# 17
